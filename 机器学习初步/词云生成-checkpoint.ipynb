# %%
txt=open("C:\\Users\\yuan\\Downloads\\piao_magelite_miqieer.txt","r",encoding='utf-8').read()

# %%
txt=txt.lower();txt
# Out:
# "书名：飘\n\n--------------------------------------------------------------------------------------------------------------------------------------\n☆本文由看帮网网友分享，仅供预览，请于下载后24小时内删除，不得用于商业用途，否则后果自负！看帮网（https://www.kanbang.cc）-精品电子书☆\n--------------------------------------------------------------------------------------------------------------------------------------\n\n目录\n第一部 \n第二部 \n第三部 \n第四部 \n第五部 \n导读 \n\n\n第一部\n\n第一章\n斯佳丽·奥哈拉长得不算美，但男人常常还来不及端详她的姿容，就被她的魅力所迷醉，比如塔尔顿家那对双胞胎兄弟，就正是如此。她脸上鲜明地糅杂着两种物质，一种是来自母方的纤细，一种则是来自父系的粗犷。她母亲出身于法国血统的海岸贵族之家，父亲则是肤色红润的爱尔兰后裔。她的脸庞特别引人注目，尖尖的下巴，方方的牙床，一双浅绿色纯净的眸子，眼角微微翘起，长长的睫毛根根挺直，浓黑的眉毛成两条斜线，挂在木兰花般的白皙肌肤上——那是南方女人极为珍爱的玉肤，出门时要用面纱、软帽和手套保护起来，不让佐治亚州的灼热阳光把它晒黑。\n一八六一年四月里的一天下午，阳光明媚。斯佳丽小姐在她爸爸那个叫做塔拉的庄园里，由塔尔顿家两兄弟——斯图尔特和布伦特陪着，坐在走廊的阴影处，显得颇为妩媚动人。她穿着一身簇新的绿色花布衣服，裙摆展开呈波浪形，脚上配着一双绿色平跟山羊皮鞋，那是她爸爸新近从亚特兰大给她买来的。这身衣服把她只有十七英寸的腰肢——邻近三个县里首屈一指的纤腰——衬托得格外窈窕。一件巴斯克紧身上衣贴着一对隆起的乳房，使这年方十六的妙龄少女，看起来相当丰满成熟。可是不管她那展开的长裙显得多么端庄，她那梳得平整的发髻多么严肃，她那交叠着放在膝盖上的雪白小手多么文静，却还是掩饰不了她的本性。在她可爱而正经的脸上，那一双绿色的眼睛显得风骚、任性、充满活力，和她那淑静的举止丝毫不
# ...

# %%
txt
# Out:
# "书名：飘\n\n--------------------------------------------------------------------------------------------------------------------------------------\n☆本文由看帮网网友分享，仅供预览，请于下载后24小时内删除，不得用于商业用途，否则后果自负！看帮网（https://www.kanbang.cc）-精品电子书☆\n--------------------------------------------------------------------------------------------------------------------------------------\n\n目录\n第一部 \n第二部 \n第三部 \n第四部 \n第五部 \n导读 \n\n\n第一部\n\n第一章\n斯佳丽·奥哈拉长得不算美，但男人常常还来不及端详她的姿容，就被她的魅力所迷醉，比如塔尔顿家那对双胞胎兄弟，就正是如此。她脸上鲜明地糅杂着两种物质，一种是来自母方的纤细，一种则是来自父系的粗犷。她母亲出身于法国血统的海岸贵族之家，父亲则是肤色红润的爱尔兰后裔。她的脸庞特别引人注目，尖尖的下巴，方方的牙床，一双浅绿色纯净的眸子，眼角微微翘起，长长的睫毛根根挺直，浓黑的眉毛成两条斜线，挂在木兰花般的白皙肌肤上——那是南方女人极为珍爱的玉肤，出门时要用面纱、软帽和手套保护起来，不让佐治亚州的灼热阳光把它晒黑。\n一八六一年四月里的一天下午，阳光明媚。斯佳丽小姐在她爸爸那个叫做塔拉的庄园里，由塔尔顿家两兄弟——斯图尔特和布伦特陪着，坐在走廊的阴影处，显得颇为妩媚动人。她穿着一身簇新的绿色花布衣服，裙摆展开呈波浪形，脚上配着一双绿色平跟山羊皮鞋，那是她爸爸新近从亚特兰大给她买来的。这身衣服把她只有十七英寸的腰肢——邻近三个县里首屈一指的纤腰——衬托得格外窈窕。一件巴斯克紧身上衣贴着一对隆起的乳房，使这年方十六的妙龄少女，看起来相当丰满成熟。可是不管她那展开的长裙显得多么端庄，她那梳得平整的发髻多么严肃，她那交叠着放在膝盖上的雪白小手多么文静，却还是掩饰不了她的本性。在她可爱而正经的脸上，那一双绿色的眼睛显得风骚、任性、充满活力，和她那淑静的举止丝毫不
# ...

# %%
import nltk #导入英文自然语言处理工具包

# %%
words=nltk.word_tokenize(txt)#英文分词

# %%
words
# Out:
# ['书名：飘',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '☆本文由看帮网网友分享，仅供预览，请于下载后24小时内删除，不得用于商业用途，否则后果自负！看帮网（https',
#  ':',
#  '//www.kanbang.cc）-精品电子书☆',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
# ...

# %%
#词干提取
from nltk.stem.porter import PorterStemmer
porter_stemmer=PorterStemmer()

# %%
#新建一个列表放入词干提取内容，以便后续逐一提取并判断其是否在停用词列表
lis=[]
for word in words:
    c=porter_stemmer.stem(word)
    lis.append(c)

# %%
lis
# Out:
# ['书名：飘',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '☆本文由看帮网网友分享，仅供预览，请于下载后24小时内删除，不得用于商业用途，否则后果自负！看帮网（http',
#  ':',
#  '//www.kanbang.cc）-精品电子书☆',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
# ...

# %%
from nltk.corpus import stopwords
stopwords
# Out:
# <WordListCorpusReader in 'C:\\Users\\yuan\\AppData\\Roaming\\nltk_data\\corpora\\stopwords'>

# %%
#查看自带的停用词列表
stop_words=stopwords.words("english")
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
#去除停用词
fitered_sentence=[w for w in lis if not w in stop_words]
fitered_sentence
# Out:
# ['书名：飘',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '☆本文由看帮网网友分享，仅供预览，请于下载后24小时内删除，不得用于商业用途，否则后果自负！看帮网（http',
#  ':',
#  '//www.kanbang.cc）-精品电子书☆',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
# ...

# %%
dist=nltk.FreqDist(fitered_sentence)#统计词频数

# %%
dist.items
# Out:
# <function FreqDist.items>

# %%
for k in dist.items():
    print(k)
# Out:
# ('书名：飘', 1)
# ('--', 268)
# ('☆本文由看帮网网友分享，仅供预览，请于下载后24小时内删除，不得用于商业用途，否则后果自负！看帮网（http', 2)
# (':', 2)
# ('//www.kanbang.cc）-精品电子书☆', 2)
# ('目录', 1)
# ('第一部', 2)
# ('第二部', 2)
# ('第三部', 2)
# ('第四部', 2)
# ('第五部', 2)
# ('导读', 2)
# ('第一章', 1)
# ('斯佳丽·奥哈拉长得不算美，但男人常常还来不及端详她的姿容，就被她的魅力所迷醉，比如塔尔顿家那对双胞胎兄弟，就正是如此。她脸上鲜明地糅杂着两种物质，一种是来自母方的纤细，一种则是来自父系的粗犷。她母亲出身于法国血统的海岸贵族之家，父亲则是肤色红润的爱尔兰后裔。她的脸庞特别引人注目，尖尖的下巴，方方的牙床，一双浅绿色纯净的眸子，眼角微微翘起，长长的睫毛根根挺直，浓黑的眉毛成两条斜线，挂在木兰花般的白皙肌肤上——那是南方女人极为珍爱的玉肤，出门时要用面纱、软帽和手套保护起来，不让佐治亚州的灼热阳光把它晒黑。', 1)
# ('一八六一年四月里的一天下午，阳光明媚。斯佳丽小姐在她爸爸那个叫做塔拉的庄园里，由塔尔顿家两兄弟——斯图尔特和布伦特陪着，坐在走廊的阴影处，显得颇为妩媚动人。她穿着一身簇新的绿色花布衣服，裙摆展开呈波浪形，脚上配着一双绿色平跟山羊皮鞋，那是她爸爸新近从亚特兰大给她买来的。这身衣服把她只有十七英寸的腰肢——邻近三个县里首屈一指的纤腰——衬托得格外窈窕。一件巴斯克紧身上衣贴着一对隆起的乳房，使这年方十六的妙龄少女，看起来相当丰满成熟。可是不管她那展开的长裙显得多么端庄，她那梳得平整的发髻多么严肃，她那交叠着放在膝盖上的雪白小手多么文静，却还是掩饰不了她的本性。在她可爱而正经的脸上，那一双绿色的眼睛显得风骚、任性、充满活力，和她那淑静的举止丝毫不能相称。她的仪态是她母亲的谆谆教诲和嬷嬷的严厉管束强加于她的，那双眼睛才真正属于她自己。', 1)
# ...

# %%
#取出字典中的键值对
for k,v in dist.items():
    print(k,v)
# Out:
# 书名：飘 1
# -- 268
# ☆本文由看帮网网友分享，仅供预览，请于下载后24小时内删除，不得用于商业用途，否则后果自负！看帮网（http 2
# : 2
# //www.kanbang.cc）-精品电子书☆ 2
# 目录 1
# 第一部 2
# 第二部 2
# 第三部 2
# 第四部 2
# 第五部 2
# 导读 2
# 第一章 1
# 斯佳丽·奥哈拉长得不算美，但男人常常还来不及端详她的姿容，就被她的魅力所迷醉，比如塔尔顿家那对双胞胎兄弟，就正是如此。她脸上鲜明地糅杂着两种物质，一种是来自母方的纤细，一种则是来自父系的粗犷。她母亲出身于法国血统的海岸贵族之家，父亲则是肤色红润的爱尔兰后裔。她的脸庞特别引人注目，尖尖的下巴，方方的牙床，一双浅绿色纯净的眸子，眼角微微翘起，长长的睫毛根根挺直，浓黑的眉毛成两条斜线，挂在木兰花般的白皙肌肤上——那是南方女人极为珍爱的玉肤，出门时要用面纱、软帽和手套保护起来，不让佐治亚州的灼热阳光把它晒黑。 1
# 一八六一年四月里的一天下午，阳光明媚。斯佳丽小姐在她爸爸那个叫做塔拉的庄园里，由塔尔顿家两兄弟——斯图尔特和布伦特陪着，坐在走廊的阴影处，显得颇为妩媚动人。她穿着一身簇新的绿色花布衣服，裙摆展开呈波浪形，脚上配着一双绿色平跟山羊皮鞋，那是她爸爸新近从亚特兰大给她买来的。这身衣服把她只有十七英寸的腰肢——邻近三个县里首屈一指的纤腰——衬托得格外窈窕。一件巴斯克紧身上衣贴着一对隆起的乳房，使这年方十六的妙龄少女，看起来相当丰满成熟。可是不管她那展开的长裙显得多么端庄，她那梳得平整的发髻多么严肃，她那交叠着放在膝盖上的雪白小手多么文静，却还是掩饰不了她的本性。在她可爱而正经的脸上，那一双绿色的眼睛显得风骚、任性、充满活力，和她那淑静的举止丝毫不能相称。她的仪态是她母亲的谆谆教诲和嬷嬷的严厉管束强加于她的，那双眼睛才真正属于她自己。 1
# 双胞胎兄弟在她身旁一边一个，懒洋洋地坐在椅子上，脚上穿着高统靴，结实的双腿交叉搁着，眼睛禁不住玻璃窗高处透射进来的阳光，眯成了一条缝。他们在随意地又谈又笑。他们今年十九岁，身高六英尺二，骨骼粗大，肌肉发达，脸晒得黝黑，有一头深赭色的头发，欢乐的目光中透露出骄纵的神情。他们穿着一模一样的蓝色外衣和芥末色马裤，看起来就像是难分彼此的一对棉桃。 1
# ...

# %%
#查看出现频数最高的30个词
most=dist.most_common(30)
most
# Out:
# [('“', 6870),
#  ('”', 6867),
#  ('--', 268),
#  ('‘', 165),
#  ('’', 163),
#  ('[', 136),
#  (']', 136),
#  ('他说，', 48),
#  ('她说，', 36),
#  ('她想，', 23),
#  ('。', 18),
#  ('哦，', 18),
#  ('不，', 18),
#  ('是的，', 14),
#  ('她说。', 14),
#  ('他说。', 13),
#  ('斯佳丽说，', 12),
#  ('她嚷道，', 12),
#  ('白瑞德说，', 11),
#  ('真的吗？', 10),
#  ('斯佳丽嚷道，', 9),
#  ('嗯，', 9),
#  ('、', 8),
#  ('哦！', 8),
#  ('斯佳丽，', 8),
#  ('我的上帝！', 8),
#  ('什么？', 7),
#  ('或者', 7),
#  ('斯佳丽想道，', 7),
#  ('可是——', 7)]

# %%
#导入词云工具包
from matplotlib import pyplot as plt
import wordcloud
from wordcloud import WordCloud

# %%
#词云制作
wordcloud=WordCloud(background_color="white",
                    width=1999,height=888,margin=5,font_path="simsun.ttc").generate(str(fitered_sentence))
plt.imshow(wordcloud)

# %%
import jieba

# %%
txt=open('C:\\Users\\yuan\\Downloads\\piao_magelite_miqieer.txt',encoding='utf-8').read();txt
# Out:
# "书名：飘\n\n--------------------------------------------------------------------------------------------------------------------------------------\n☆本文由看帮网网友分享，仅供预览，请于下载后24小时内删除，不得用于商业用途，否则后果自负！看帮网（https://www.kanbang.cc）-精品电子书☆\n--------------------------------------------------------------------------------------------------------------------------------------\n\n目录\n第一部 \n第二部 \n第三部 \n第四部 \n第五部 \n导读 \n\n\n第一部\n\n第一章\n斯佳丽·奥哈拉长得不算美，但男人常常还来不及端详她的姿容，就被她的魅力所迷醉，比如塔尔顿家那对双胞胎兄弟，就正是如此。她脸上鲜明地糅杂着两种物质，一种是来自母方的纤细，一种则是来自父系的粗犷。她母亲出身于法国血统的海岸贵族之家，父亲则是肤色红润的爱尔兰后裔。她的脸庞特别引人注目，尖尖的下巴，方方的牙床，一双浅绿色纯净的眸子，眼角微微翘起，长长的睫毛根根挺直，浓黑的眉毛成两条斜线，挂在木兰花般的白皙肌肤上——那是南方女人极为珍爱的玉肤，出门时要用面纱、软帽和手套保护起来，不让佐治亚州的灼热阳光把它晒黑。\n一八六一年四月里的一天下午，阳光明媚。斯佳丽小姐在她爸爸那个叫做塔拉的庄园里，由塔尔顿家两兄弟——斯图尔特和布伦特陪着，坐在走廊的阴影处，显得颇为妩媚动人。她穿着一身簇新的绿色花布衣服，裙摆展开呈波浪形，脚上配着一双绿色平跟山羊皮鞋，那是她爸爸新近从亚特兰大给她买来的。这身衣服把她只有十七英寸的腰肢——邻近三个县里首屈一指的纤腰——衬托得格外窈窕。一件巴斯克紧身上衣贴着一对隆起的乳房，使这年方十六的妙龄少女，看起来相当丰满成熟。可是不管她那展开的长裙显得多么端庄，她那梳得平整的发髻多么严肃，她那交叠着放在膝盖上的雪白小手多么文静，却还是掩饰不了她的本性。在她可爱而正经的脸上，那一双绿色的眼睛显得风骚、任性、充满活力，和她那淑静的举止丝毫不
# ...

# %%
words=jieba.lcut(txt)

# %%
words
# Out:
# ['书名',
#  '：',
#  '飘',
#  '\n',
#  '\n',
#  '--------------------------------------------------------------------------------------------------------------------------------------',
#  '\n',
#  '☆',
#  '本文',
#  '由',
#  '看',
#  '帮网',
#  '网友',
#  '分享',
#  '，',
#  '仅供',
#  '预览',
#  '，',
#  '请',
#  '于',
#  '下载',
#  '后',
#  '24',
#  '小时',
#  '内',
#  '删除',
#  '，',
#  '不得',
#  '用于',
#  '商业用途',
#  '，',
#  '否则',
#  '后果自负',
#  '！',
#  '看帮网',
#  '（',
#  'https',
#  ':',
#  '/',
#  '/',
#  'www',
#  '.',
#  'kanbang',
#  '.',
#  'cc',
#  '）',
#  '-',
#  '精品',
#  '电子书',
#  '☆',
#  '\n',
#  '--------------------------------------------------------------------------------------------------------------------------------------',
#  '\n',
#  '\n',
#  '目录',
#  '\n',
#  '第一部',
#  ' ',
#  '\n',
#  '第二部',
#  ' ',
#  '\n',
#  '第三部',
#  ' ',
#  '\n',
#  '第四部',
#  ' ',
#  '\n',
#  '第五部',
#  ' ',
#  '\n',
#  '导读',
#  ' ',
#  '\n',
#  '\n',
#  '\n',
#  '第一部',
#  '\n',
#  '\n',
#  '第一章',
#  '\n',
#  '斯佳丽',
# ...

# %%
stp = open("C:\\Users\\yuan\\Downloads\\piao_magelite_miqieer.txt", "r", encoding='utf-8').read()

# %%
stp
# Out:
# "书名：飘\n\n--------------------------------------------------------------------------------------------------------------------------------------\n☆本文由看帮网网友分享，仅供预览，请于下载后24小时内删除，不得用于商业用途，否则后果自负！看帮网（https://www.kanbang.cc）-精品电子书☆\n--------------------------------------------------------------------------------------------------------------------------------------\n\n目录\n第一部 \n第二部 \n第三部 \n第四部 \n第五部 \n导读 \n\n\n第一部\n\n第一章\n斯佳丽·奥哈拉长得不算美，但男人常常还来不及端详她的姿容，就被她的魅力所迷醉，比如塔尔顿家那对双胞胎兄弟，就正是如此。她脸上鲜明地糅杂着两种物质，一种是来自母方的纤细，一种则是来自父系的粗犷。她母亲出身于法国血统的海岸贵族之家，父亲则是肤色红润的爱尔兰后裔。她的脸庞特别引人注目，尖尖的下巴，方方的牙床，一双浅绿色纯净的眸子，眼角微微翘起，长长的睫毛根根挺直，浓黑的眉毛成两条斜线，挂在木兰花般的白皙肌肤上——那是南方女人极为珍爱的玉肤，出门时要用面纱、软帽和手套保护起来，不让佐治亚州的灼热阳光把它晒黑。\n一八六一年四月里的一天下午，阳光明媚。斯佳丽小姐在她爸爸那个叫做塔拉的庄园里，由塔尔顿家两兄弟——斯图尔特和布伦特陪着，坐在走廊的阴影处，显得颇为妩媚动人。她穿着一身簇新的绿色花布衣服，裙摆展开呈波浪形，脚上配着一双绿色平跟山羊皮鞋，那是她爸爸新近从亚特兰大给她买来的。这身衣服把她只有十七英寸的腰肢——邻近三个县里首屈一指的纤腰——衬托得格外窈窕。一件巴斯克紧身上衣贴着一对隆起的乳房，使这年方十六的妙龄少女，看起来相当丰满成熟。可是不管她那展开的长裙显得多么端庄，她那梳得平整的发髻多么严肃，她那交叠着放在膝盖上的雪白小手多么文静，却还是掩饰不了她的本性。在她可爱而正经的脸上，那一双绿色的眼睛显得风骚、任性、充满活力，和她那淑静的举止丝毫不
# ...

# %%
c=stp.split("\n");c
# Out:
# ['书名：飘',
#  '',
#  '--------------------------------------------------------------------------------------------------------------------------------------',
#  '☆本文由看帮网网友分享，仅供预览，请于下载后24小时内删除，不得用于商业用途，否则后果自负！看帮网（https://www.kanbang.cc）-精品电子书☆',
#  '--------------------------------------------------------------------------------------------------------------------------------------',
#  '',
#  '目录',
#  '第一部 ',
#  '第二部 ',
#  '第三部 ',
#  '第四部 ',
#  '第五部 ',
#  '导读 ',
#  '',
#  '',
#  '第一部',
#  '',
#  '第一章',
#  '斯佳丽·奥哈拉长得不算美，但男人常常还来不及端详她的姿容，就被她的魅力所迷醉，比如塔尔顿家那对双胞胎兄弟，就正是如此。她脸上鲜明地糅杂着两种物质，一种是来自母方的纤细，一种则是来自父系的粗犷。她母亲出身于法国血统的海岸贵族之家，父亲则是肤色红润的爱尔兰后裔。她的脸庞特别引人注目，尖尖的下巴，方方的牙床，一双浅绿色纯净的眸子，眼角微微翘起，长长的睫毛根根挺直，浓黑的眉毛成两条斜线，挂在木兰花般的白皙肌肤上——那是南方女人极为珍爱的玉肤，出门时要用面纱、软帽和手套保护起来，不让佐治亚州的灼热阳光把它晒黑。',
# ...

# %%
filtered_sentence=[w for w in words if not w in c];filtered_sentence
# Out:
# ['书名',
#  '：',
#  '飘',
#  '\n',
#  '\n',
#  '\n',
#  '☆',
#  '本文',
#  '由',
#  '看',
#  '帮网',
#  '网友',
#  '分享',
#  '，',
#  '仅供',
#  '预览',
#  '，',
#  '请',
#  '于',
#  '下载',
#  '后',
#  '24',
#  '小时',
#  '内',
#  '删除',
#  '，',
#  '不得',
#  '用于',
#  '商业用途',
#  '，',
#  '否则',
#  '后果自负',
#  '！',
#  '看帮网',
#  '（',
#  'https',
#  ':',
#  '/',
#  '/',
#  'www',
#  '.',
#  'kanbang',
#  '.',
#  'cc',
#  '）',
#  '-',
#  '精品',
#  '电子书',
#  '☆',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  ' ',
#  '\n',
#  ' ',
#  '\n',
#  ' ',
#  '\n',
#  ' ',
#  '\n',
#  ' ',
#  '\n',
#  ' ',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '斯佳丽',
#  '·',
#  '奥',
#  '哈拉',
#  '长得',
#  '不算',
#  '美',
#  '，',
#  '但',
#  '男人',
#  '常常',
#  '还',
#  '来不及',
#  '端详',
#  '她',
#  '的',
#  '姿容',
#  '，',
#  '就',
#  '被',
#  '她',
#  '的',
#  '魅力',
#  '所',
#  '迷醉',
#  '，',
#  '比如',
#  '塔',
#  '尔顿',
#  '家',
#  '那',
#  '对',
#  '双胞胎',
#  '兄弟',
#  '，',
#  '就',
#  '正是如此',
#  '。',
#  '她',
#  '脸上',
#  '鲜明',
#  '地',
#  '糅杂',
#  '着',
# ...

# %%
#python字典的get方法会返回指定键的值,dict.get(‘键’),返回“键”对应的“值”,如果键不在字典中则返回默认值None
#过滤掉所有长度为1的词语
#合并同义词并进行词频统计
counts={}
for word in filtered_sentence:
    if len(word)==1:
        continue
    elif word=="白瑞德":
        rword="白船长"
    elif word=="斯佳丽":
        rword=="斯佳丽"
    else:
        rword=word
    counts[rword]=counts.get(rword,0)+1

# %%
counts.items()
# Out:
# dict_items([('书名', 1), ('本文', 2), ('帮网', 2), ('网友', 2), ('分享', 6), ('仅供', 2), ('预览', 2), ('下载', 2), ('24', 4), ('小时', 33), ('删除', 2), ('不得', 13), ('用于', 6), ('商业用途', 2), ('否则', 34), ('后果自负', 2), ('看帮网', 2), ('https', 2), ('www', 2), ('kanbang', 2), ('cc', 2), ('精品', 4), ('电子书', 3), ('哈拉', 161), ('长得', 34), ('不算', 15), ('男人', 488), ('常常', 82), ('来不及', 15), ('端详', 7), ('姿容', 1), ('魅力', 37), ('迷醉', 8), ('比如', 37), ('尔顿', 180), ('双胞胎', 19), ('兄弟', 81), ('正是如此', 2), ('脸上', 331), ('鲜明', 7), ('糅杂', 1), ('两种', 19), ('物质', 3), ('一种', 336), ('来自', 37), ('母方', 1), ('纤细', 8), ('父系', 1), ('粗犷', 3), ('母亲', 277), ('出身', 23), ('法国', 18), ('血统', 11), ('海岸', 3), ('贵族', 14), ('父亲', 171), ('肤色', 5), ('红润', 9), ('爱尔兰', 54), ('后裔', 2), ('脸庞', 13), ('特别', 75), ('引人注目', 10), ('尖尖', 1), ('下巴', 49), ('方方', 4), ('牙床', 10), ('一双', 73), ('浅绿色', 7), ('纯净', 1), ('眸子', 6), ('眼角', 8), ('微微', 28), ('翘起', 8), ('长长的', 38), ('睫毛', 26), ('根根', 3), ('挺直', 16), ('浓黑', 2), ('眉毛', 25), ('两条', 17), ('斜线', 1), ('木兰花', 3), ('般的
# ...

# %%
#将元素加入列表以便索引
items=list(counts.items())
items
# Out:
# [('书名', 1),
#  ('本文', 2),
#  ('帮网', 2),
#  ('网友', 2),
#  ('分享', 6),
#  ('仅供', 2),
#  ('预览', 2),
#  ('下载', 2),
#  ('24', 4),
#  ('小时', 33),
#  ('删除', 2),
#  ('不得', 13),
#  ('用于', 6),
#  ('商业用途', 2),
#  ('否则', 34),
#  ('后果自负', 2),
#  ('看帮网', 2),
#  ('https', 2),
#  ('www', 2),
#  ('kanbang', 2),
#  ('cc', 2),
#  ('精品', 4),
#  ('电子书', 3),
#  ('哈拉', 161),
#  ('长得', 34),
#  ('不算', 15),
#  ('男人', 488),
#  ('常常', 82),
#  ('来不及', 15),
#  ('端详', 7),
#  ('姿容', 1),
#  ('魅力', 37),
#  ('迷醉', 8),
#  ('比如', 37),
#  ('尔顿', 180),
#  ('双胞胎', 19),
#  ('兄弟', 81),
#  ('正是如此', 2),
#  ('脸上', 331),
#  ('鲜明', 7),
#  ('糅杂', 1),
#  ('两种', 19),
#  ('物质', 3),
#  ('一种', 336),
#  ('来自', 37),
#  ('母方', 1),
#  ('纤细', 8),
#  ('父系', 1),
#  ('粗犷', 3),
#  ('母亲', 277),
#  ('出身', 23),
#  ('法国', 18),
#  ('血统', 11),
#  ('海岸', 3),
#  ('贵族', 14),
#  ('父亲', 171),
#  ('肤色', 5),
#  ('红润', 9),
#  ('爱尔兰', 54),
#  ('后裔', 2),
#  ('脸庞', 13),
#  ('特别', 75),
#  ('引人注目', 10),
#  ('尖尖', 1),
#  ('下巴', 49),
#  ('方方', 4),
#  ('牙床', 10),
# ...

# %%
items[3]
# Out:
# ('网友', 2)

# %%
a=items.sort(key=lambda x:x[1],reverse=True)
a

# %%
for i in range(len(items)):
    word,count=items[i]
    print(word,count)
# Out:
# 可是 2436
# 他们 2421
# 没有 1914
# 一个 1525
# 自己 1341
# 什么 1263
# 我们 1250
# 白船长 1246
# 现在 1216
# 知道 1127
# 艾希礼 1037
# 因为 980
# 媚兰 939
# 孩子 848
# 这样 842
# 她们 778
# 那么 740
# 不是 732
# 太太 709
# 可以 690
# 女人 659
# 起来 651
# 小姐 648
# 觉得 642
# 北佬 637
# 怎么 628
# 已经 626
# 一样 571
# 而且 566
# 塔拉 562
# 不过 545
# 亚特兰大 540
# 的话 532
# 不会 520
# 心里 516
# 不能 509
# 时候 507
# 男人 488
# 那样 470
# 嬷嬷 457
# 眼睛 445
# 不要 445
# 感到 430
# 皮特 429
# 一定 427
# 这里 413
# 那些 410
# 东西 404
# 喜欢 400
# 就是 395
# 这个 394
# 一点 380
# 像是 379
# 杰拉尔 378
# 要是 370
# 为什么 367
# 弗兰克 366
# 说道 364
# 这些 363
# 黑人 357
# 非常 347
# 这种 343
# 还是 342
# 样子 341
# 一种 336
# 脸上 331
# 还有 328
# 那里 327
# 先生 326
# 上帝 326
# 听见 322
# 以后 321
# 一直 319
# 如果 316
# 看见 315
# 地方 313
# 似的 311
# 明白 311
# 出来 310
# 身上 307
# 埃伦 303
# 声音 298
# 南方 295
# 只要 295
# 看到 295
# 只有 293
# 看着 292
# 家里 290
# 简直 289
# 母亲 277
# 姑妈 272
# 威尔克斯 269
# 媚利 268
# 希望 267
# 一起 265
# 两个 263
# 可能 263
# 人家 261
# 为了 260
# 一下 260
# 马车 259
# 坐在 258
# 能够 258
# 真的 258
# 韦德 257
# 那个 256
# 生活 256
# 几个 256
# ...

# %%
c=WordCloud(background_color="black",width=1500,height=1000,margin=10,font_path="simsun.ttc").generate(str(items))

# %%
plt.imshow(c)
